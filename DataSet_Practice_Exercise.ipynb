# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan2079/Data-Science-Training/blob/main/DataSet_Practice_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# URL to the Kaggle dataset's CSV file
csv_url = '/content/drive/MyDrive/KEC Training Dataset/mobile phone price prediction.csv'

# Read the CSV file directly from the URL into a DataFrame
df = pd.read_csv(csv_url)

df
# Out:
#       Unnamed: 0                                  Name  Rating  Spec_score  \
# 0              0                 Samsung Galaxy F14 5G    4.65          68
# 1              1                    Samsung Galaxy A11    4.20          63
# 2              2                    Samsung Galaxy A13    4.30          75
# 3              3                    Samsung Galaxy F23    4.10          73
# 4              4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
# ...          ...                                   ...     ...         ...
# 1365        1365                               TCL 40R    4.05          75
# 1366        1366                 TCL 50 XL NxtPaper 5G    4.10          80
# 1367        1367                 TCL 50 XE NxtPaper 5G    4.00          80
# 1368        1368                    TCL 40 NxtPaper 5G    4.50          79
# 1369        1369                           TCL Trifold    4.65          93
#
# ...

# %% [markdown]
# ## How many rows and columns are there in the dataset?

# %%
df.shape
# Out:
# (1370, 18)

# %% [markdown]
# ## What are the column names and their data types?

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Name                  object
# Rating               float64
# Spec_score             int64
# No_of_sim             object
# Ram                   object
# Battery               object
# Display               object
# Camera                object
# External_Memory       object
# Android_version       object
# Price                 object
# company               object
# Inbuilt_memory        object
# fast_charging         object
# Screen_resolution     object
# Processor             object
# Processor_name        object
# dtype: object

# %% [markdown]
# ## What are the summary statistics (mean, median, min, max, etc.) for numerical columns?

# %%
df.describe()
# Out:
#         Unnamed: 0       Rating   Spec_score
# count  1370.000000  1370.000000  1370.000000
# mean    684.500000     4.374416    80.234307
# std     395.629246     0.230176     8.373922
# min       0.000000     3.750000    42.000000
# 25%     342.250000     4.150000    75.000000
# 50%     684.500000     4.400000    82.000000
# 75%    1026.750000     4.550000    86.000000
# max    1369.000000     4.750000    98.000000

# %% [markdown]
# ## Are there any missing values in the dataset? If so, how many in each column?

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Name                   0
# Rating                 0
# Spec_score             0
# No_of_sim              0
# Ram                    0
# Battery                0
# Display                0
# Camera                 0
# External_Memory        0
# Android_version      443
# Price                  0
# company                0
# Inbuilt_memory        19
# fast_charging         89
# Screen_resolution      2
# Processor             28
# Processor_name         0
# dtype: int64

# %% [markdown]
# ## How can you select rows where the value in the 'price' is less than 10k using loc?

# %%
df.loc[df['Spec_score']>90]
# Out:
#       Unnamed: 0                                      Name  Rating  \
# 51            51                        Samsung Galaxy A76    4.75
# 76            76             Samsung Galaxy Z Fold 6 Ultra    4.05
# 77            77  Samsung Galaxy Z Fold 5 (12GB RAM + 1TB)    4.45
# 78            78                   Samsung Galaxy Z Fold 6    4.45
# 79            79                   Samsung Galaxy Z Fold 4    4.75
# ...          ...                                       ...     ...
# 1286        1286                   Huawei Mate 40 Pro Plus    4.55
# 1287        1287          Huawei Mate 40 RS Porsche Design    4.30
# 1288        1288                            Huawei P40 Pro    4.65
# 1292        1292                            Huawei P70 Art    4.50
# 1369        1369                               TCL Trifold    4.65
#
#       Spec_score                            No_of_sim             Ram  \
# 51            91        Dual Sim, 3G, 4G, 5G, VoLTE,         8 GB RAM
# ...

# %% [markdown]
# ## How can you set the value of 'column1' to 0 for rows where 'column2' is equal to 'value' using loc?

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df.loc[df['Price']>10000,'Rating']=0
df
# Out:
#       Unnamed: 0                                  Name  Rating  Spec_score  \
# 0              0                 Samsung Galaxy F14 5G    4.65          68
# 1              1                    Samsung Galaxy A11    4.20          63
# 2              2                    Samsung Galaxy A13    4.30          75
# 3              3                    Samsung Galaxy F23    4.10          73
# 4              4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
# ...          ...                                   ...     ...         ...
# 1365        1365                               TCL 40R    4.05          75
# 1366        1366                 TCL 50 XL NxtPaper 5G    4.10          80
# 1367        1367                 TCL 50 XE NxtPaper 5G    4.00          80
# 1368        1368                    TCL 40 NxtPaper 5G    4.50          79
# 1369        1369                           TCL Trifold    4.65          93
#
# ...

# %%
df_numeric = pd.to_numeric(df['Price'])
df_numeric
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1365   NaN
# 1366   NaN
# 1367   NaN
# 1368   NaN
# 1369   NaN
# Name: Price, Length: 1370, dtype: float64

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b666bf274d0a> in <cell line: 1>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined
