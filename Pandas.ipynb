# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan2079/Data-Science-Training/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# ### in vs code notebook we use %pip intall pandas
# ### in anaconda notebook we use !pip install pandas
# ### in google collab we dont need to do anything

# %%
import pandas as pd #pandas for data manipulation and working with data

# %% [markdown]
# pandas has two things in it. DATAFRAME and SERIES.
# dataframes are those in which columns are defined.
# and series are those which makes up a dataframes.
#
# like dataframes are columns and series are like entries/rows in a column

# %%
people = {
    'first' : ['ram','hari','gopal'],
    'last' : ['sharma','yadav','verma'],
    'email' : ['ram@gmail.com','hari@yahoo.com','gopal@hotmail.com']
}

# %%
people['email']
# Out:
# ['ram@gmail.com', 'hari@yahoo.com', 'gopal@hotmail.com']

# %%
people.get('email')
# Out:
# ['ram@gmail.com', 'hari@yahoo.com', 'gopal@hotmail.com']

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#    first    last              email
# 0    ram  sharma      ram@gmail.com
# 1   hari   yadav     hari@yahoo.com
# 2  gopal   verma  gopal@hotmail.com

# %%
type(people_df)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(people_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %% [markdown]
# ### access in a dataframe??

# %%
people_df.get('email')
# Out:
# 0        ram@gmail.com
# 1       hari@yahoo.com
# 2    gopal@hotmail.com
# Name: email, dtype: object

# %%
people_df['email']
# Out:
# 0        ram@gmail.com
# 1       hari@yahoo.com
# 2    gopal@hotmail.com
# Name: email, dtype: object

# %% [markdown]
# accessing multiple columns

# %%
people_df.get(['email','first'])
# Out:
#                email  first
# 0      ram@gmail.com    ram
# 1     hari@yahoo.com   hari
# 2  gopal@hotmail.com  gopal

# %% [markdown]
# ### by default head() only gives u first 5 data in the dataset. but we can display any number of data by giving parameters

# %%
people_df.head(2)
# Out:
#   first    last           email
# 0   ram  sharma   ram@gmail.com
# 1  hari   yadav  hari@yahoo.com

# %% [markdown]
# ### by default tail() only gives u last 5 data in the dataset. but we can display any number of data by giving parameters

# %%
people_df.tail(2)
# Out:
#    first   last              email
# 1   hari  yadav     hari@yahoo.com
# 2  gopal  verma  gopal@hotmail.com

# %% [markdown]
# ### info gives the information that about the dataset in your system

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   3 non-null      object
#  1   last    3 non-null      object
#  2   email   3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %% [markdown]
# ### describe() only works with int but gives u the sum, mean,etc

# %%
people_df.describe()
# Out:
#        first    last          email
# count      3       3              3
# unique     3       3              3
# top      ram  sharma  ram@gmail.com
# freq       1       1              1

# %% [markdown]
# ### columns gives u all the columns in the dataframe and also gives u their types

# %%
people_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# ### using iloc and loc. loc works with label while iloc works with idex

# %% [markdown]
# here the first parameter sorts for the row while the second parameter sorts through the columns

# %% [markdown]
# also the syntax for pandas functions use [] for functions

# %%
people_df.iloc[[0,2,1],[0,2]]
# Out:
#    first              email
# 0    ram      ram@gmail.com
# 2  gopal  gopal@hotmail.com
# 1   hari     hari@yahoo.com

# %% [markdown]
# with loc we can use both the index and the label to access the dataframe

# %%
people_df.loc[[0,2,1],['email','first']]
# Out:
#                email  first
# 0      ram@gmail.com    ram
# 2  gopal@hotmail.com  gopal
# 1     hari@yahoo.com   hari

# %%
people_df.iloc[0:2,0:2]
# Out:
#   first    last
# 0   ram  sharma
# 1  hari   yadav

# %% [markdown]
# people = {
#     'first': [
#         'Ram', 'Hari', 'Gopal', 'Isabella', 'Oliver', 'Sophia', 'Elijah', 'Emma',
#         'William', 'Ava'
#     ],
#     'last': [
#         'Sharma', 'Yadav', 'Verma', 'Smith', 'Johnson', 'Brown', 'Davis', 'Miller',
#         'Wilson', 'Moore'
#     ],
#     'email': [
#         'ram@gmail.com', 'hari@yahoo.com', 'gopal@hotmail.com', 'isabella@example.com',
#         'oliver@example.com', 'sophia@example.com', 'elijah@example.com', 'emma@example.com',
#         'william@example.com', 'ava@example.com'
#     ]
# }
#
#
# Access 3rd to 7th row with iloc
# Access 4th to 8th row with loc
# Access the first and last name of 4th index
# using loc and iloc both
# Access first, last, and email of 5 to 7th index
# using loc and iloc both

# %%
people_dataset = {
    'first': [
        'Ram', 'Hari', 'Gopal', 'Isabella', 'Oliver', 'Sophia', 'Elijah', 'Emma',
        'William', 'Ava'
    ],
    'last': [
        'Sharma', 'Yadav', 'Verma', 'Smith', 'Johnson', 'Brown', 'Davis', 'Miller',
        'Wilson', 'Moore'
    ],
    'email': [
        'ram@gmail.com', 'hari@yahoo.com', 'gopal@hotmail.com', 'isabella@example.com',
        'oliver@example.com', 'sophia@example.com', 'elijah@example.com', 'emma@example.com',
        'william@example.com', 'ava@example.com'
    ]
}


# Access 3rd to 7th row with iloc
# Access 4th to 8th row with loc
# Access the first and last name of 4th index
# using loc and iloc both
# Access first, last, and email of 5 to 7th index
# using loc and iloc both

# %%
manche_df=pd.DataFrame(people_dataset)

# %%
print(manche_df)
# Out:
#       first     last                 email
# 0       Ram   Sharma         ram@gmail.com
# 1      Hari    Yadav        hari@yahoo.com
# 2     Gopal    Verma     gopal@hotmail.com
# 3  Isabella    Smith  isabella@example.com
# 4    Oliver  Johnson    oliver@example.com
# 5    Sophia    Brown    sophia@example.com
# 6    Elijah    Davis    elijah@example.com
# 7      Emma   Miller      emma@example.com
# 8   William   Wilson   william@example.com
# 9       Ava    Moore       ava@example.com

# %%
manche_df.head()
# Out:
#       first     last                 email
# 0       Ram   Sharma         ram@gmail.com
# 1      Hari    Yadav        hari@yahoo.com
# 2     Gopal    Verma     gopal@hotmail.com
# 3  Isabella    Smith  isabella@example.com
# 4    Oliver  Johnson    oliver@example.com

# %%
manche_df.tail()
# Out:
#      first    last                email
# 5   Sophia   Brown   sophia@example.com
# 6   Elijah   Davis   elijah@example.com
# 7     Emma  Miller     emma@example.com
# 8  William  Wilson  william@example.com
# 9      Ava   Moore      ava@example.com

# %%
manche_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   10 non-null     object
#  1   last    10 non-null     object
#  2   email   10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %%
manche_df.describe()
# Out:
#        first    last          email
# count     10      10             10
# unique    10      10             10
# top      Ram  Sharma  ram@gmail.com
# freq       1       1              1

# %%
manche_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
manche_df.iloc[[1,2,4,5],[0,1]]
# Out:
#     first     last
# 1    Hari    Yadav
# 2   Gopal    Verma
# 4  Oliver  Johnson
# 5  Sophia    Brown

# %%
manche_df.iloc[1:3,0:2]
# Out:
#    first   last
# 1   Hari  Yadav
# 2  Gopal  Verma

# %%
manche_df.loc[[1,2,3,4],['first','email']]
# Out:
#       first                 email
# 1      Hari        hari@yahoo.com
# 2     Gopal     gopal@hotmail.com
# 3  Isabella  isabella@example.com
# 4    Oliver    oliver@example.com
